# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fp_growth import *
import pandas as pd

# %%
itemSetList = [['eggs', 'bacon', 'soup'],
                ['eggs', 'bacon', 'apple'],
                ['soup', 'bacon', 'banana']]
itemSetList2 = [
    ['f', 'a', 'c', 'd', 'g', 'i', 'm', 'p'],
    ['a', 'b', 'c', 'f', 'l', 'm', 'o'],
    ['b', 'f', 'h', 'j', 'o'],
    ['b', 'c', 'k', 's', 'p'],
    ['a', 'f', 'c', 'e', 'l', 'p', 'm', 'n']
]

# %%
model = MyFPGrowth(itemSetList2, 0.5)

# %%
model.genFpTree()

# %%
graph = model.drawTree()

# %%
graph

# %%
table = model.associationRules()

# %%
table
# Out:
#   alpha                                           patterns
# 0     p                                     [(p,), (p, c)]
# 1     m  [(m,), (m, a), (m, f), (m, c), (m, a, f), (m, ...
# 2     b                                             [(b,)]
# 3     a                  [(a,), (a, f), (a, c), (a, f, c)]
# 4     f                                     [(f,), (f, c)]
# 5     c                                             [(c,)]
